# %%
#import all needed packages
import pandas as pd

# %%
#let get our data from my github repo
dataset = pd.read_csv("https://raw.githubusercontent.com/pinocchiovirus/public_data/main/datasets/train.Ar.csv")
dataset.head(51)
# Out:
#     id  ... dialect
# 0    1  ...    nile
# 1    2  ...    nile
# 2    3  ...    nile
# 3    4  ...  magreb
# 4    5  ...    nile
# 5    6  ...    nile
# 6    7  ...    nile
# 7    8  ...    nile
# 8    9  ...    nile
# 9   10  ...     msa
# 10  11  ...    nile
# 11  12  ...    nile
# 12  13  ...    nile
# 13  14  ...    nile
# 14  15  ...    nile
# 15  16  ...    nile
# 16  17  ...     msa
# 17  18  ...    nile
# 18  19  ...  magreb
# 19  20  ...     msa
# 20  21  ...  magreb
# 21  22  ...    nile
# 22  23  ...    nile
# 23  24  ...  magreb
# 24  25  ...  magreb
# 25  26  ...    nile
# 26  27  ...    nile
# 27  28  ...  magreb
# 28  29  ...    nile
# 29  30  ...    nile
# 30  31  ...    nile
# 31  32  ...  magreb
# 32  33  ...  magreb
# 33  34  ...    nile
# 34  35  ...    nile
# 35  36  ...    nile
# 36  37  ...    nile
# 37  38  ...    gulf
# 38  39  ...    nile
# 39  40  ...    nile
# 40  41  ...    nile
# 41  42  ...     msa
# 42  43  ...    nile
# 43  44  ...  levant
# ...
